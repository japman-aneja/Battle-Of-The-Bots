# %%
# Imports
import torch
import numpy as np
import gymnasium as gym
from collections import deque
import pygame
import random
import torch.nn as nn

# %%
# DQN model which takes in the state as an input and outputs predicted q values for every possible action
class DQN(torch.nn.Module):
    def __init__(self, state_space, action_space):
        super().__init__()
        # Add your architecture parameters here
        # You can use nn.Functional
        # Remember that the input is of size batch_size x state_space
        # and the output is of size batch_size x action_space (ulta ho sakta hai dekh lo)
        # TODO: Add code here
        self.fc1 = nn.Linear(state_space, 128)
        self.fc2 = nn.Linear(128, 128)
        self.out = nn.Linear(128, action_space)

    def forward(self, input):
        # TODO: Complete based on your implementation
        x = input
        x = torch.relu(self.fc1(x))
        x = torch.relu(self.fc2(x))
        return self.out(x)

# %%
# While training neural networks, we split the data into batches.
# To improve the training, we need to remove the "correlation" between game states
# The buffer starts storing states and once it reaches maximum capacity, it replaces
# states at random which reduces the correlation.
class ExperienceBuffer:
    def __init__(self, capacity):
        self.buffer = deque(maxlen=capacity)

    def push(self, state, action, reward, next_state, done):
        self.buffer.append((state, action, reward, next_state, done))

    def sample(self, batch_size):
        batch = random.sample(self.buffer, batch_size)
        states, actions, rewards, next_states, dones = zip(*batch)
        return states, actions, rewards, next_states, dones

    def __len__(self):
        return len(self.buffer)

# %%
class ChaseEscapeEnv(gym.Env):
    metadata = {"render_modes": ["human"], "render_fps": 30}

    def __init__(self, render_mode=None):
        super().__init__()

        self.dt = 0.1
        self.max_speed = 0.4
        self.agent_radius = 0.05
        self.target_radius = 0.05
        self.chaser_radius = 0.07
        self.chaser_speed = 0.03
        self.steps = 0
        self.max_steps = 200

        self.action_space = gym.spaces.MultiDiscrete([3, 3])  # actions in {0,1,2} map to [-1,0,1]
        self.observation_space = gym.spaces.Box(
            low=-1,
            high=1,
            shape=(8,),
            dtype=np.float32,
        )

        self.render_mode = render_mode
        self.screen_size = 500
        self.np_random = None

        if render_mode == "human":
            pygame.init()
            self.screen = pygame.display.set_mode((self.screen_size, self.screen_size))
            self.clock = pygame.time.Clock()

    def sample_pos(self, far_from=None, min_dist=0.5):
        while True:
            pos = self.np_random.uniform(low=-0.8, high=0.8, size=(2,))
            if far_from is None or np.linalg.norm(pos - far_from) >= min_dist:
                return pos

    def reset(self, seed=None, options=None):
        super().reset(seed=seed)
        self.steps = 0
        self.agent_pos = self.sample_pos()
        self.agent_vel = np.zeros(2, dtype=np.float32)
        self.target_pos = self.sample_pos(far_from=self.agent_pos, min_dist=0.5)
        self.chaser_pos = self.sample_pos(far_from=self.agent_pos, min_dist=0.7)

        return self._get_obs(), {}

    def _get_obs(self):
        # TODO: Decide how to pass the state (don't use pixel values)
        # Observation is concatenation of positions and velocity:
        # [agent_x, agent_y, agent_vx, agent_vy, target_x, target_y, chaser_x, chaser_y]
        obs = np.concatenate((
            self.agent_pos,
            self.agent_vel,
            self.target_pos,
            self.chaser_pos
        )).astype(np.float32)
        return obs

    def _get_info(self):
        return {}

    def step(self, action):
        # TODO: Add reward scheme
        # 1) Try to make the agent stay within bounds
        # 2) The agent shouldn't idle around
        # 3) The agent should go for the reward
        # 4) The agent should avoid the chaser

        self.steps += 1

        # Map discrete actions to acceleration values (-1, 0, +1)
        accel = (np.array(action) - 1) * 0.1
        self.agent_vel += accel
        self.agent_vel = np.clip(self.agent_vel, -self.max_speed, self.max_speed)
        self.agent_pos += self.agent_vel * self.dt

        # Keep agent inside bounds [-1, 1]
        self.agent_pos = np.clip(self.agent_pos, -1, 1)

        # Move chaser towards agent
        direction = self.agent_pos - self.chaser_pos
        dist = np.linalg.norm(direction)
        if dist > 1e-5:
            self.chaser_pos += self.chaser_speed * direction / dist

        # Compute distances
        dist_to_target = np.linalg.norm(self.agent_pos - self.target_pos)
        dist_to_chaser = np.linalg.norm(self.agent_pos - self.chaser_pos)

        reward = 0.0

        if(dist_to_chaser < dist_to_target) :
          reward += 0.5
        else :
          reward -= 0.5


        terminated = False

        # Reward for reaching target
        if dist_to_target < self.agent_radius + self.target_radius:
            reward += 10.0
            self.target_pos = self.sample_pos(far_from=self.agent_pos, min_dist=0.5)

        # Terminate if caught by chaser
        if dist_to_chaser < self.agent_radius + self.chaser_radius:
            reward -= 10.0
            terminated = True

        # Small per-timestep penalty to encourage quick behavior
        reward -= 0.01

        # Optional: truncate episode after max steps
        truncated = self.steps >= self.max_steps

        return self._get_obs(), reward, terminated, truncated, {}

    def render(self):
        if self.render_mode != "human":
            return

        for event in pygame.event.get():
            if event.type == pygame.QUIT:
                self.close()

        self.screen.fill((255, 255, 255))

        def to_screen(p):
            x = int((p[0] + 1) / 2 * self.screen_size)
            y = int((1 - (p[1] + 1) / 2) * self.screen_size)
            return x, y

        pygame.draw.circle(self.screen, (0, 255, 0), to_screen(self.target_pos), int(self.target_radius * self.screen_size))
        pygame.draw.circle(self.screen, (0, 0, 255), to_screen(self.agent_pos), int(self.agent_radius * self.screen_size))
        pygame.draw.circle(self.screen, (255, 0, 0), to_screen(self.chaser_pos), int(self.chaser_radius * self.screen_size))

        pygame.display.flip()
        self.clock.tick(self.metadata["render_fps"])

    def close(self):
        if self.render_mode == "human":
            pygame.quit()

# %%
import torch
import torch.nn as nn
import torch.optim as optim
import random

env = ChaseEscapeEnv(render_mode=None)
obs_shape = env.observation_space.shape[0]  # 8
n_actions = np.prod(env.action_space.nvec)  # 3 * 3 = 9 possible action pairs

# Your DQN model should take 8 inputs and output 9 Q-values (for each action pair)
model = DQN(obs_shape, n_actions)
target_model = DQN(obs_shape, n_actions)
target_model.load_state_dict(model.state_dict())

optimizer = optim.Adam(model.parameters(), lr=1e-3)
buffer = ExperienceBuffer(10000)
batch_size = 64
gamma = 0.99
epsilon_start = 1.0
epsilon_final = 0.05
epsilon_decay = 10000
epsilon = epsilon_start
steps_done = 0

def select_action(state):
    global steps_done, epsilon
    steps_done += 1
    epsilon = epsilon_final + (epsilon_start - epsilon_final) * \
              np.exp(-1. * steps_done / epsilon_decay)
    if random.random() < epsilon:
        # Sample random discrete actions for 2 dimensions:
        a1 = random.choice([0,1,2])
        a2 = random.choice([0,1,2])
        action = a1 * 3 + a2  # encode to single int from 0 to 8
        return torch.tensor([[action]], dtype=torch.long)
    else:
        with torch.no_grad():
            state = torch.FloatTensor(state).unsqueeze(0)
            q_values = model(state)
            action = q_values.max(1)[1].view(1,1)
            return action

def decode_action(action_idx):
    # inverse of a1 * 3 + a2 encoding
    a1 = action_idx // 3
    a2 = action_idx % 3
    return [a1, a2]

# Training loop sketch
num_episodes = 1000
for episode in range(num_episodes):
    state, _ = env.reset()
    total_reward = 0
    done = False

    while not done:
        action_idx = select_action(state).item()
        action = decode_action(action_idx)
        next_state, reward, terminated, truncated, _ = env.step(action)
        done = terminated or truncated
        buffer.push(state.copy(), action_idx, reward, next_state.copy(), done)
        state = next_state
        total_reward += reward

        # Sample from buffer and train model here (omitted for brevity)
        # ...

    print(f"Episode {episode} Total Reward: {total_reward:.2f}")

env.close()
# Out:
# Episode 0 Total Reward: 4.70
# Episode 1 Total Reward: 16.95
# Episode 2 Total Reward: 18.87
# Episode 3 Total Reward: 1.17
# Episode 4 Total Reward: 7.89
# Episode 5 Total Reward: 20.83
# Episode 6 Total Reward: 1.97
# Episode 7 Total Reward: -2.65
# Episode 8 Total Reward: -0.20
# Episode 9 Total Reward: -30.76
# Episode 10 Total Reward: 12.54
# Episode 11 Total Reward: 6.71
# Episode 12 Total Reward: -4.03
# Episode 13 Total Reward: 12.91
# Episode 14 Total Reward: 12.03
# Episode 15 Total Reward: 14.81
# Episode 16 Total Reward: -2.52
# Episode 17 Total Reward: 10.30
# Episode 18 Total Reward: 15.48
# Episode 19 Total Reward: 1.27
# Episode 20 Total Reward: -6.36
# Episode 21 Total Reward: 14.01
# Episode 22 Total Reward: 0.62
# Episode 23 Total Reward: 22.75
# Episode 24 Total Reward: -13.79
# Episode 25 Total Reward: 7.64
# Episode 26 Total Reward: 16.32
# Episode 27 Total Reward: -4.22
# Episode 28 Total Reward: -9.20
# Episode 29 Total Reward: 2.25
# Episode 30 Total Reward: 7.15
# Episode 31 Total Reward: 16.46
# Episode 32 Total Reward: -0.69
# Episode 33 Total Reward: 4.70
# Episode 34 Total Reward: 7.58
# Episode 35 Total Reward: -9.67
# Episode 36 Total Reward: -3.63
# Episode 37 Total Reward: 33.10
# Episode 38 Total Reward: 10.09
# Episode 39 Total Reward: -5.14
# Episode 40 Total Reward: 11.89
# Episode 41 Total Reward: 24.79
# Episode 42 Total Reward: 15.97
# Episode 43 Total Reward: -19.30
# Episode 44 Total Reward: 3.75
# Episode 45 Total Reward: 14.50
# Episode 46 Total Reward: 3.36
# Episode 47 Total Reward: -2.01
# Episode 48 Total Reward: -18.79
# Episode 49 Total Reward: 23.81
# Episode 50 Total Reward: -11.11
# Episode 51 Total Reward: 11.97
# Episode 52 Total Reward: 8.05
# Episode 53 Total Reward: -1.28
# Episode 54 Total Reward: -3.73
# Episode 55 Total Reward: 12.20
# Episode 56 Total Reward: -16.71
# Episode 57 Total Reward: -2.16
# Episode 58 Total Reward: 15.34
# Episode 59 Total Reward: 13.44
# Episode 60 Total Reward: 11.93
# Episode 61 Total Reward: -5.20
# Episode 62 Total Reward: -1.11
# Episode 63 Total Reward: 28.71
# Episode 64 Total Reward: 25.28
# Episode 65 Total Reward: 22.32
# Episode 66 Total Reward: 15.97
# Episode 67 Total Reward: -16.19
# Episode 68 Total Reward: 14.50
# Episode 69 Total Reward: -0.69
# Episode 70 Total Reward: 26.75
# Episode 71 Total Reward: 0.09
# Episode 72 Total Reward: -22.11
# Episode 73 Total Reward: 5.83
# Episode 74 Total Reward: -15.64
# Episode 75 Total Reward: 17.44
# Episode 76 Total Reward: 14.83
# Episode 77 Total Reward: 23.32
# Episode 78 Total Reward: 6.01
# Episode 79 Total Reward: -12.22
# Episode 80 Total Reward: 16.46
# Episode 81 Total Reward: -0.71
# Episode 82 Total Reward: 24.28
# Episode 83 Total Reward: -0.20
# Episode 84 Total Reward: -7.97
# Episode 85 Total Reward: 7.44
# Episode 86 Total Reward: 11.52
# Episode 87 Total Reward: 19.40
# Episode 88 Total Reward: 5.89
# Episode 89 Total Reward: 19.40
# Episode 90 Total Reward: 17.93
# Episode 91 Total Reward: 19.40
# Episode 92 Total Reward: -1.66
# Episode 93 Total Reward: 17.30
# Episode 94 Total Reward: -4.17
# Episode 95 Total Reward: 23.40
# Episode 96 Total Reward: 13.93
# Episode 97 Total Reward: -2.83
# Episode 98 Total Reward: -8.20
# Episode 99 Total Reward: -5.10
# Episode 100 Total Reward: -8.25
# Episode 101 Total Reward: 13.44
# Episode 102 Total Reward: 18.91
# Episode 103 Total Reward: 3.23
# Episode 104 Total Reward: 26.26
# Episode 105 Total Reward: 18.91
# Episode 106 Total Reward: -15.19
# Episode 107 Total Reward: 6.28
# Episode 108 Total Reward: 15.48
# Episode 109 Total Reward: 23.81
# Episode 110 Total Reward: 8.48
# Episode 111 Total Reward: 5.65
# Episode 112 Total Reward: -15.19
# Episode 113 Total Reward: 12.87
# Episode 114 Total Reward: 18.42
# Episode 115 Total Reward: 8.52
# Episode 116 Total Reward: 6.26
# Episode 117 Total Reward: 19.34
# Episode 118 Total Reward: 18.91
# Episode 119 Total Reward: 17.44
# Episode 120 Total Reward: -18.66
# Episode 121 Total Reward: 5.50
# Episode 122 Total Reward: -0.72
# Episode 123 Total Reward: 3.87
# Episode 124 Total Reward: -8.12
# Episode 125 Total Reward: 15.97
# Episode 126 Total Reward: 4.85
# Episode 127 Total Reward: 3.48
# Episode 128 Total Reward: 22.83
# Episode 129 Total Reward: 7.44
# Episode 130 Total Reward: -2.18
# Episode 131 Total Reward: 2.25
# Episode 132 Total Reward: -0.50
# Episode 133 Total Reward: 8.95
# Episode 134 Total Reward: 3.11
# Episode 135 Total Reward: 7.50
# Episode 136 Total Reward: 12.54
# Episode 137 Total Reward: 11.83
# Episode 138 Total Reward: 7.99
# Episode 139 Total Reward: -1.07
# Episode 140 Total Reward: 13.52
# Episode 141 Total Reward: 10.30
# Episode 142 Total Reward: 11.56
# Episode 143 Total Reward: -12.65
# Episode 144 Total Reward: 5.89
# Episode 145 Total Reward: 10.54
# Episode 146 Total Reward: 10.09
# Episode 147 Total Reward: 26.75
# Episode 148 Total Reward: 20.87
# Episode 149 Total Reward: 4.46
# Episode 150 Total Reward: 20.28
# Episode 151 Total Reward: 14.01
# Episode 152 Total Reward: -1.67
# Episode 153 Total Reward: -0.11
# Episode 154 Total Reward: 5.93
# Episode 155 Total Reward: 8.46
# Episode 156 Total Reward: 14.93
# Episode 157 Total Reward: 22.34
# Episode 158 Total Reward: -13.65
# Episode 159 Total Reward: -7.66
# Episode 160 Total Reward: 3.32
# Episode 161 Total Reward: -7.19
# Episode 162 Total Reward: 13.38
# Episode 163 Total Reward: 10.58
# Episode 164 Total Reward: -5.15
# Episode 165 Total Reward: 14.50
# Episode 166 Total Reward: 8.56
# Episode 167 Total Reward: 12.87
# Episode 168 Total Reward: -6.12
# Episode 169 Total Reward: 12.05
# Episode 170 Total Reward: 19.40
# Episode 171 Total Reward: 22.34
# Episode 172 Total Reward: 16.44
# Episode 173 Total Reward: 7.81
# Episode 174 Total Reward: 1.03
# Episode 175 Total Reward: 24.79
# Episode 176 Total Reward: 20.87
# Episode 177 Total Reward: 13.03
# Episode 178 Total Reward: 17.93
# Episode 179 Total Reward: -2.56
# Episode 180 Total Reward: 16.38
# Episode 181 Total Reward: 7.32
# Episode 182 Total Reward: 14.50
# Episode 183 Total Reward: -5.10
# Episode 184 Total Reward: 6.30
# Episode 185 Total Reward: 14.46
# Episode 186 Total Reward: -3.21
# Episode 187 Total Reward: 16.95
# Episode 188 Total Reward: -3.63
# Episode 189 Total Reward: 18.42
# Episode 190 Total Reward: 19.89
# Episode 191 Total Reward: 18.42
# Episode 192 Total Reward: 8.26
# Episode 193 Total Reward: 14.50
# Episode 194 Total Reward: -5.24
# Episode 195 Total Reward: -18.21
# Episode 196 Total Reward: 34.59
# Episode 197 Total Reward: 7.83
# Episode 198 Total Reward: 13.26
# Episode 199 Total Reward: 14.50
# Episode 200 Total Reward: -9.14
# Episode 201 Total Reward: 21.36
# Episode 202 Total Reward: -1.67
# Episode 203 Total Reward: 20.87
# Episode 204 Total Reward: 10.28
# Episode 205 Total Reward: 16.46
# Episode 206 Total Reward: 21.85
# Episode 207 Total Reward: -2.17
# Episode 208 Total Reward: -10.31
# Episode 209 Total Reward: 13.03
# Episode 210 Total Reward: -2.68
# Episode 211 Total Reward: 3.46
# Episode 212 Total Reward: 14.50
# Episode 213 Total Reward: -7.22
# Episode 214 Total Reward: 14.50
# Episode 215 Total Reward: 9.83
# Episode 216 Total Reward: 16.46
# Episode 217 Total Reward: 14.42
# Episode 218 Total Reward: 9.60
# Episode 219 Total Reward: 18.42
# Episode 220 Total Reward: 25.28
# Episode 221 Total Reward: 0.21
# Episode 222 Total Reward: 8.99
# Episode 223 Total Reward: 19.38
# Episode 224 Total Reward: -19.74
# Episode 225 Total Reward: 21.30
# Episode 226 Total Reward: 3.83
# Episode 227 Total Reward: 24.30
# Episode 228 Total Reward: -5.22
# Episode 229 Total Reward: 17.44
# Episode 230 Total Reward: -2.58
# Episode 231 Total Reward: 11.89
# Episode 232 Total Reward: -4.12
# Episode 233 Total Reward: 10.09
# Episode 234 Total Reward: 17.89
# Episode 235 Total Reward: 14.48
# Episode 236 Total Reward: 25.77
# Episode 237 Total Reward: 8.58
# Episode 238 Total Reward: 18.91
# Episode 239 Total Reward: -27.17
# Episode 240 Total Reward: 12.32
# Episode 241 Total Reward: 7.32
# Episode 242 Total Reward: -4.61
# Episode 243 Total Reward: 15.97
# Episode 244 Total Reward: -7.60
# Episode 245 Total Reward: -5.16
# Episode 246 Total Reward: 16.95
# Episode 247 Total Reward: 22.34
# Episode 248 Total Reward: -14.16
# Episode 249 Total Reward: -1.67
# Episode 250 Total Reward: 5.97
# Episode 251 Total Reward: 9.03
# Episode 252 Total Reward: 9.05
# Episode 253 Total Reward: 27.24
# Episode 254 Total Reward: 10.48
# Episode 255 Total Reward: 10.93
# Episode 256 Total Reward: -4.27
# Episode 257 Total Reward: -4.58
# Episode 258 Total Reward: 14.95
# Episode 259 Total Reward: 0.44
# Episode 260 Total Reward: 2.68
# Episode 261 Total Reward: 17.93
# Episode 262 Total Reward: 15.71
# Episode 263 Total Reward: 9.03
# Episode 264 Total Reward: 12.38
# Episode 265 Total Reward: -22.72
# Episode 266 Total Reward: 11.07
# Episode 267 Total Reward: 15.48
# Episode 268 Total Reward: 18.38
# Episode 269 Total Reward: 22.26
# Episode 270 Total Reward: 14.50
# Episode 271 Total Reward: 4.30
# Episode 272 Total Reward: -21.66
# Episode 273 Total Reward: 22.83
# Episode 274 Total Reward: 11.38
# Episode 275 Total Reward: 15.97
# Episode 276 Total Reward: 8.93
# Episode 277 Total Reward: 14.01
# Episode 278 Total Reward: -19.25
# Episode 279 Total Reward: 12.93
# Episode 280 Total Reward: -4.70
# Episode 281 Total Reward: -3.31
# Episode 282 Total Reward: 6.83
# Episode 283 Total Reward: -5.10
# Episode 284 Total Reward: -3.09
# Episode 285 Total Reward: -2.23
# Episode 286 Total Reward: 9.93
# Episode 287 Total Reward: 16.95
# Episode 288 Total Reward: 16.95
# Episode 289 Total Reward: -17.64
# Episode 290 Total Reward: 12.54
# Episode 291 Total Reward: 18.40
# Episode 292 Total Reward: -3.14
# Episode 293 Total Reward: 16.30
# Episode 294 Total Reward: 8.46
# Episode 295 Total Reward: -3.14
# Episode 296 Total Reward: -1.67
# Episode 297 Total Reward: -34.11
# Episode 298 Total Reward: 1.60
# Episode 299 Total Reward: -15.69
# Episode 300 Total Reward: -4.66
# Episode 301 Total Reward: 18.42
# Episode 302 Total Reward: 14.46
# Episode 303 Total Reward: 15.89
# Episode 304 Total Reward: 13.52
# Episode 305 Total Reward: 0.85
# Episode 306 Total Reward: 6.52
# Episode 307 Total Reward: 13.48
# Episode 308 Total Reward: 14.50
# Episode 309 Total Reward: 17.44
# Episode 310 Total Reward: 12.01
# Episode 311 Total Reward: 17.44
# Episode 312 Total Reward: 18.91
# Episode 313 Total Reward: 9.91
# Episode 314 Total Reward: 15.36
# Episode 315 Total Reward: 23.95
# Episode 316 Total Reward: -0.20
# Episode 317 Total Reward: -7.10
# Episode 318 Total Reward: 15.38
# Episode 319 Total Reward: 12.48
# Episode 320 Total Reward: -12.61
# Episode 321 Total Reward: -5.14
# Episode 322 Total Reward: -3.16
# Episode 323 Total Reward: 7.64
# Episode 324 Total Reward: -9.19
# Episode 325 Total Reward: 3.89
# Episode 326 Total Reward: -16.70
# Episode 327 Total Reward: -2.50
# Episode 328 Total Reward: 3.62
# Episode 329 Total Reward: -5.10
# Episode 330 Total Reward: -10.29
# Episode 331 Total Reward: 21.36
# Episode 332 Total Reward: 13.42
# Episode 333 Total Reward: 29.20
# Episode 334 Total Reward: 16.46
# Episode 335 Total Reward: -5.10
# Episode 336 Total Reward: 11.07
# Episode 337 Total Reward: 16.38
# Episode 338 Total Reward: 22.83
# Episode 339 Total Reward: 16.46
# Episode 340 Total Reward: 10.32
# Episode 341 Total Reward: 0.85
# Episode 342 Total Reward: 27.24
# Episode 343 Total Reward: 5.38
# Episode 344 Total Reward: -11.54
# Episode 345 Total Reward: -13.19
# Episode 346 Total Reward: -13.68
# Episode 347 Total Reward: 3.99
# Episode 348 Total Reward: 11.54
# Episode 349 Total Reward: 25.71
# Episode 350 Total Reward: 18.42
# Episode 351 Total Reward: 19.89
# Episode 352 Total Reward: -13.64
# Episode 353 Total Reward: -2.48
# Episode 354 Total Reward: 12.01
# Episode 355 Total Reward: 13.44
# Episode 356 Total Reward: 14.01
# Episode 357 Total Reward: 18.42
# Episode 358 Total Reward: -0.69
# Episode 359 Total Reward: 25.28
# Episode 360 Total Reward: 7.64
# Episode 361 Total Reward: -2.60
# Episode 362 Total Reward: 10.58
# Episode 363 Total Reward: 1.01
# Episode 364 Total Reward: 14.42
# Episode 365 Total Reward: -2.07
# Episode 366 Total Reward: 8.60
# Episode 367 Total Reward: -18.11
# Episode 368 Total Reward: 27.73
# Episode 369 Total Reward: -2.65
# Episode 370 Total Reward: 4.48
# Episode 371 Total Reward: 4.48
# Episode 372 Total Reward: 4.93
# Episode 373 Total Reward: 19.30
# Episode 374 Total Reward: -6.72
# Episode 375 Total Reward: -13.14
# Episode 376 Total Reward: 11.38
# Episode 377 Total Reward: 21.85
# Episode 378 Total Reward: -2.65
# Episode 379 Total Reward: -2.16
# Episode 380 Total Reward: 10.99
# Episode 381 Total Reward: 13.75
# Episode 382 Total Reward: 15.97
# Episode 383 Total Reward: 15.91
# Episode 384 Total Reward: 13.95
# Episode 385 Total Reward: 19.40
# Episode 386 Total Reward: 12.85
# Episode 387 Total Reward: 16.93
# Episode 388 Total Reward: -8.59
# Episode 389 Total Reward: -6.19
# Episode 390 Total Reward: 7.13
# Episode 391 Total Reward: -12.67
# Episode 392 Total Reward: 8.30
# Episode 393 Total Reward: 20.38
# Episode 394 Total Reward: 9.34
# Episode 395 Total Reward: 9.46
# Episode 396 Total Reward: -4.44
# Episode 397 Total Reward: 12.99
# Episode 398 Total Reward: 11.07
# Episode 399 Total Reward: 17.34
# Episode 400 Total Reward: 20.87
# Episode 401 Total Reward: 17.89
# Episode 402 Total Reward: 13.03
# Episode 403 Total Reward: 15.44
# Episode 404 Total Reward: 12.05
# Episode 405 Total Reward: 15.46
# Episode 406 Total Reward: 20.87
# Episode 407 Total Reward: 2.42
# Episode 408 Total Reward: 7.46
# Episode 409 Total Reward: 13.91
# Episode 410 Total Reward: 18.91
# Episode 411 Total Reward: -3.14
# Episode 412 Total Reward: -5.15
# Episode 413 Total Reward: 24.30
# Episode 414 Total Reward: 15.97
# Episode 415 Total Reward: 16.93
# Episode 416 Total Reward: 4.87
# Episode 417 Total Reward: 14.50
# Episode 418 Total Reward: 11.07
# Episode 419 Total Reward: 20.38
# Episode 420 Total Reward: 13.32
# Episode 421 Total Reward: 19.81
# Episode 422 Total Reward: -14.14
# Episode 423 Total Reward: 16.95
# Episode 424 Total Reward: 5.97
# Episode 425 Total Reward: -4.61
# Episode 426 Total Reward: 7.64
# Episode 427 Total Reward: 18.89
# Episode 428 Total Reward: 15.97
# Episode 429 Total Reward: 21.36
# Episode 430 Total Reward: 11.46
# Episode 431 Total Reward: 7.03
# Episode 432 Total Reward: 2.28
# Episode 433 Total Reward: 17.93
# Episode 434 Total Reward: 1.42
# Episode 435 Total Reward: 21.36
# Episode 436 Total Reward: 15.48
# Episode 437 Total Reward: 20.87
# Episode 438 Total Reward: 16.79
# Episode 439 Total Reward: 5.99
# Episode 440 Total Reward: -7.63
# Episode 441 Total Reward: 11.56
# Episode 442 Total Reward: -9.20
# Episode 443 Total Reward: 15.48
# Episode 444 Total Reward: 6.18
# Episode 445 Total Reward: 14.99
# Episode 446 Total Reward: 12.44
# Episode 447 Total Reward: -0.71
# Episode 448 Total Reward: -6.99
# Episode 449 Total Reward: 7.54
# Episode 450 Total Reward: 23.32
# Episode 451 Total Reward: -7.10
# Episode 452 Total Reward: 5.66
# Episode 453 Total Reward: 14.50
# Episode 454 Total Reward: 10.91
# Episode 455 Total Reward: 13.03
# Episode 456 Total Reward: 16.95
# Episode 457 Total Reward: 19.85
# Episode 458 Total Reward: 19.81
# Episode 459 Total Reward: -3.63
# Episode 460 Total Reward: 12.05
# Episode 461 Total Reward: -7.61
# Episode 462 Total Reward: -8.83
# Episode 463 Total Reward: -14.58
# Episode 464 Total Reward: 1.40
# Episode 465 Total Reward: 11.36
# Episode 466 Total Reward: 23.81
# Episode 467 Total Reward: 25.22
# Episode 468 Total Reward: -21.15
# Episode 469 Total Reward: -4.61
# Episode 470 Total Reward: 23.73
# Episode 471 Total Reward: -15.63
# Episode 472 Total Reward: 19.40
# Episode 473 Total Reward: -3.62
# Episode 474 Total Reward: 7.46
# Episode 475 Total Reward: -2.05
# Episode 476 Total Reward: 7.05
# Episode 477 Total Reward: 17.32
# Episode 478 Total Reward: -2.16
# Episode 479 Total Reward: 14.32
# Episode 480 Total Reward: 19.34
# Episode 481 Total Reward: -3.14
# Episode 482 Total Reward: 20.38
# Episode 483 Total Reward: 10.09
# Episode 484 Total Reward: 9.46
# Episode 485 Total Reward: -12.11
# Episode 486 Total Reward: 9.85
# Episode 487 Total Reward: -2.60
# Episode 488 Total Reward: -4.66
# Episode 489 Total Reward: 21.91
# Episode 490 Total Reward: -16.15
# Episode 491 Total Reward: 4.91
# Episode 492 Total Reward: -5.59
# Episode 493 Total Reward: 10.75
# Episode 494 Total Reward: 17.79
# Episode 495 Total Reward: 14.01
# Episode 496 Total Reward: -16.24
# Episode 497 Total Reward: 20.83
# Episode 498 Total Reward: -9.19
# Episode 499 Total Reward: -7.63
# Episode 500 Total Reward: 13.44
# Episode 501 Total Reward: -10.52
# Episode 502 Total Reward: 17.85
# Episode 503 Total Reward: 10.28
# Episode 504 Total Reward: -17.11
# Episode 505 Total Reward: 3.91
# Episode 506 Total Reward: 9.42
# Episode 507 Total Reward: -3.60
# Episode 508 Total Reward: 20.30
# Episode 509 Total Reward: 6.15
# Episode 510 Total Reward: 5.05
# Episode 511 Total Reward: -8.22
# Episode 512 Total Reward: -10.74
# Episode 513 Total Reward: 1.69
# Episode 514 Total Reward: -2.67
# Episode 515 Total Reward: 14.01
# Episode 516 Total Reward: 9.11
# Episode 517 Total Reward: 18.91
# Episode 518 Total Reward: -10.16
# Episode 519 Total Reward: -0.54
# Episode 520 Total Reward: 6.93
# Episode 521 Total Reward: 7.87
# Episode 522 Total Reward: -13.70
# Episode 523 Total Reward: -17.68
# Episode 524 Total Reward: -0.17
# Episode 525 Total Reward: -14.16
# Episode 526 Total Reward: 10.58
# Episode 527 Total Reward: -17.91
# Episode 528 Total Reward: 22.34
# Episode 529 Total Reward: -0.15
# Episode 530 Total Reward: 10.85
# Episode 531 Total Reward: 10.97
# Episode 532 Total Reward: 13.52
# Episode 533 Total Reward: -4.62
# Episode 534 Total Reward: 19.40
# Episode 535 Total Reward: 16.46
# Episode 536 Total Reward: -10.69
# Episode 537 Total Reward: -11.17
# Episode 538 Total Reward: 10.50
# Episode 539 Total Reward: 10.03
# Episode 540 Total Reward: 15.97
# Episode 541 Total Reward: -5.59
# Episode 542 Total Reward: 22.34
# Episode 543 Total Reward: 10.09
# Episode 544 Total Reward: 8.97
# Episode 545 Total Reward: -12.78
# Episode 546 Total Reward: 19.40
# Episode 547 Total Reward: -3.14
# Episode 548 Total Reward: 12.01
# Episode 549 Total Reward: -2.16
# Episode 550 Total Reward: -2.16
# Episode 551 Total Reward: -16.66
# Episode 552 Total Reward: 18.91
# Episode 553 Total Reward: 14.99
# Episode 554 Total Reward: -7.15
# Episode 555 Total Reward: 19.89
# Episode 556 Total Reward: 17.44
# Episode 557 Total Reward: 8.62
# Episode 558 Total Reward: 0.85
# Episode 559 Total Reward: 7.01
# Episode 560 Total Reward: -3.71
# Episode 561 Total Reward: 19.89
# Episode 562 Total Reward: 4.30
# Episode 563 Total Reward: 6.64
# Episode 564 Total Reward: 23.30
# Episode 565 Total Reward: 20.38
# Episode 566 Total Reward: 7.64
# Episode 567 Total Reward: 17.32
# Episode 568 Total Reward: -0.69
# Episode 569 Total Reward: 15.42
# Episode 570 Total Reward: 25.28
# Episode 571 Total Reward: 33.61
# Episode 572 Total Reward: 18.91
# Episode 573 Total Reward: 14.50
# Episode 574 Total Reward: -15.15
# Episode 575 Total Reward: 15.40
# Episode 576 Total Reward: 16.93
# Episode 577 Total Reward: 13.03
# Episode 578 Total Reward: 13.03
# Episode 579 Total Reward: 16.38
# Episode 580 Total Reward: -19.70
# Episode 581 Total Reward: -10.85
# Episode 582 Total Reward: -23.70
# Episode 583 Total Reward: 12.03
# Episode 584 Total Reward: 23.32
# Episode 585 Total Reward: -23.68
# Episode 586 Total Reward: 11.01
# Episode 587 Total Reward: 3.44
# Episode 588 Total Reward: -4.61
# Episode 589 Total Reward: 6.36
# Episode 590 Total Reward: 21.85
# Episode 591 Total Reward: 15.44
# Episode 592 Total Reward: 7.09
# Episode 593 Total Reward: -5.61
# Episode 594 Total Reward: -5.13
# Episode 595 Total Reward: 6.66
# Episode 596 Total Reward: 5.34
# Episode 597 Total Reward: -17.15
# Episode 598 Total Reward: -16.64
# Episode 599 Total Reward: 24.79
# Episode 600 Total Reward: -5.10
# Episode 601 Total Reward: 24.79
# Episode 602 Total Reward: 10.58
# Episode 603 Total Reward: 18.91
# Episode 604 Total Reward: 7.91
# Episode 605 Total Reward: 23.81
# Episode 606 Total Reward: 19.32
# Episode 607 Total Reward: 17.93
# Episode 608 Total Reward: 6.52
# Episode 609 Total Reward: 8.40
# Episode 610 Total Reward: -19.01
# Episode 611 Total Reward: -14.24
# Episode 612 Total Reward: -2.65
# Episode 613 Total Reward: 6.99
# Episode 614 Total Reward: 14.50
# Episode 615 Total Reward: -5.10
# Episode 616 Total Reward: 1.40
# Episode 617 Total Reward: 14.50
# Episode 618 Total Reward: 5.09
# Episode 619 Total Reward: 23.81
# Episode 620 Total Reward: 22.34
# Episode 621 Total Reward: 16.79
# Episode 622 Total Reward: 18.36
# Episode 623 Total Reward: 22.83
# Episode 624 Total Reward: 7.91
# Episode 625 Total Reward: 5.85
# Episode 626 Total Reward: -9.67
# Episode 627 Total Reward: 6.97
# Episode 628 Total Reward: 13.95
# Episode 629 Total Reward: 18.91
# Episode 630 Total Reward: 16.46
# Episode 631 Total Reward: 14.01
# Episode 632 Total Reward: 19.89
# Episode 633 Total Reward: 17.83
# Episode 634 Total Reward: 16.81
# Episode 635 Total Reward: 10.36
# Episode 636 Total Reward: -10.63
# Episode 637 Total Reward: 1.36
# Episode 638 Total Reward: 4.69
# Episode 639 Total Reward: 9.83
# Episode 640 Total Reward: -18.66
# Episode 641 Total Reward: 9.97
# Episode 642 Total Reward: -0.11
# Episode 643 Total Reward: 28.22
# Episode 644 Total Reward: -21.19
# Episode 645 Total Reward: 13.03
# Episode 646 Total Reward: 17.44
# Episode 647 Total Reward: 21.85
# Episode 648 Total Reward: -2.72
# Episode 649 Total Reward: -2.70
# Episode 650 Total Reward: 22.34
# Episode 651 Total Reward: 17.93
# Episode 652 Total Reward: 17.44
# Episode 653 Total Reward: -2.69
# Episode 654 Total Reward: 16.95
# Episode 655 Total Reward: 3.46
# Episode 656 Total Reward: 10.09
# Episode 657 Total Reward: 7.91
# Episode 658 Total Reward: 15.97
# Episode 659 Total Reward: 1.22
# Episode 660 Total Reward: 23.81
# Episode 661 Total Reward: 4.15
# Episode 662 Total Reward: 17.44
# Episode 663 Total Reward: -3.63
# Episode 664 Total Reward: -0.21
# Episode 665 Total Reward: 10.44
# Episode 666 Total Reward: 10.73
# Episode 667 Total Reward: 4.89
# Episode 668 Total Reward: 9.46
# Episode 669 Total Reward: 23.32
# Episode 670 Total Reward: 14.50
# Episode 671 Total Reward: 17.93
# Episode 672 Total Reward: -3.63
# Episode 673 Total Reward: 16.91
# Episode 674 Total Reward: 21.28
# Episode 675 Total Reward: 5.99
# Episode 676 Total Reward: 13.89
# Episode 677 Total Reward: -5.42
# Episode 678 Total Reward: 17.36
# Episode 679 Total Reward: -3.63
# Episode 680 Total Reward: 8.13
# Episode 681 Total Reward: 10.97
# Episode 682 Total Reward: 17.93
# Episode 683 Total Reward: -16.76
# Episode 684 Total Reward: 12.24
# Episode 685 Total Reward: -14.29
# Episode 686 Total Reward: 11.32
# Episode 687 Total Reward: 25.28
# Episode 688 Total Reward: -9.60
# Episode 689 Total Reward: 13.03
# Episode 690 Total Reward: -11.64
# Episode 691 Total Reward: 16.95
# Episode 692 Total Reward: 4.54
# Episode 693 Total Reward: 9.42
# Episode 694 Total Reward: 25.28
# Episode 695 Total Reward: 8.42
# Episode 696 Total Reward: 7.34
# Episode 697 Total Reward: 13.46
# Episode 698 Total Reward: 4.42
# Episode 699 Total Reward: -4.61
# Episode 700 Total Reward: 8.34
# Episode 701 Total Reward: 9.93
# Episode 702 Total Reward: -2.65
# Episode 703 Total Reward: 15.81
# Episode 704 Total Reward: -3.64
# Episode 705 Total Reward: 17.93
# Episode 706 Total Reward: 7.05
# Episode 707 Total Reward: -0.69
# Episode 708 Total Reward: 15.40
# Episode 709 Total Reward: 21.85
# Episode 710 Total Reward: -8.62
# Episode 711 Total Reward: -13.65
# Episode 712 Total Reward: -10.18
# Episode 713 Total Reward: -14.69
# Episode 714 Total Reward: -2.09
# Episode 715 Total Reward: 12.05
# Episode 716 Total Reward: 12.54
# Episode 717 Total Reward: 5.19
# Episode 718 Total Reward: 26.75
# Episode 719 Total Reward: 9.52
# Episode 720 Total Reward: -10.68
# Episode 721 Total Reward: 17.44
# Episode 722 Total Reward: 7.03
# Episode 723 Total Reward: 5.09
# Episode 724 Total Reward: -5.10
# Episode 725 Total Reward: -3.05
# Episode 726 Total Reward: 3.97
# Episode 727 Total Reward: 4.34
# Episode 728 Total Reward: 11.38
# Episode 729 Total Reward: 15.97
# Episode 730 Total Reward: -14.17
# Episode 731 Total Reward: -24.25
# Episode 732 Total Reward: 0.52
# Episode 733 Total Reward: 16.95
# Episode 734 Total Reward: 3.01
# Episode 735 Total Reward: -10.05
# Episode 736 Total Reward: 0.29
# Episode 737 Total Reward: 10.91
# Episode 738 Total Reward: 7.15
# Episode 739 Total Reward: 7.89
# Episode 740 Total Reward: 20.87
# Episode 741 Total Reward: 15.48
# Episode 742 Total Reward: -1.64
# Episode 743 Total Reward: -13.20
# Episode 744 Total Reward: 18.91
# Episode 745 Total Reward: 9.60
# Episode 746 Total Reward: -21.01
# Episode 747 Total Reward: -9.61
# Episode 748 Total Reward: 30.67
# Episode 749 Total Reward: 13.46
# Episode 750 Total Reward: 14.48
# Episode 751 Total Reward: 7.40
# Episode 752 Total Reward: 17.89
# Episode 753 Total Reward: 14.99
# Episode 754 Total Reward: 5.48
# Episode 755 Total Reward: 7.64
# Episode 756 Total Reward: 11.44
# Episode 757 Total Reward: -5.42
# Episode 758 Total Reward: 6.66
# Episode 759 Total Reward: 14.91
# Episode 760 Total Reward: 11.89
# Episode 761 Total Reward: 9.03
# Episode 762 Total Reward: 33.12
# Episode 763 Total Reward: 6.44
# Episode 764 Total Reward: -3.14
# Episode 765 Total Reward: 24.87
# Episode 766 Total Reward: -12.11
# Episode 767 Total Reward: 12.52
# Episode 768 Total Reward: 10.09
# Episode 769 Total Reward: 13.85
# Episode 770 Total Reward: 24.79
# Episode 771 Total Reward: -2.22
# Episode 772 Total Reward: 6.66
# Episode 773 Total Reward: 11.73
# Episode 774 Total Reward: -4.12
# Episode 775 Total Reward: 11.91
# Episode 776 Total Reward: 8.99
# Episode 777 Total Reward: -2.27
# Episode 778 Total Reward: 0.48
# Episode 779 Total Reward: 14.99
# Episode 780 Total Reward: 8.40
# Episode 781 Total Reward: 3.48
# Episode 782 Total Reward: 18.42
# Episode 783 Total Reward: 17.93
# Episode 784 Total Reward: -2.65
# Episode 785 Total Reward: 12.44
# Episode 786 Total Reward: 13.89
# Episode 787 Total Reward: 13.01
# Episode 788 Total Reward: -7.60
# Episode 789 Total Reward: -10.17
# Episode 790 Total Reward: 0.81
# Episode 791 Total Reward: -10.16
# Episode 792 Total Reward: -11.13
# Episode 793 Total Reward: 12.99
# Episode 794 Total Reward: 20.50
# Episode 795 Total Reward: -5.10
# Episode 796 Total Reward: -9.40
# Episode 797 Total Reward: 2.11
# Episode 798 Total Reward: -22.15
# Episode 799 Total Reward: -7.12
# Episode 800 Total Reward: 13.44
# Episode 801 Total Reward: 12.54
# Episode 802 Total Reward: 15.48
# Episode 803 Total Reward: -17.64
# Episode 804 Total Reward: 8.36
# Episode 805 Total Reward: -3.68
# Episode 806 Total Reward: 0.81
# Episode 807 Total Reward: -1.46
# Episode 808 Total Reward: 3.23
# Episode 809 Total Reward: -8.19
# Episode 810 Total Reward: 17.93
# Episode 811 Total Reward: 16.95
# Episode 812 Total Reward: 5.95
# Episode 813 Total Reward: -7.10
# Episode 814 Total Reward: 10.97
# Episode 815 Total Reward: 23.32
# Episode 816 Total Reward: 7.64
# Episode 817 Total Reward: -3.97
# Episode 818 Total Reward: 8.62
# Episode 819 Total Reward: -15.17
# Episode 820 Total Reward: 11.91
# Episode 821 Total Reward: 16.44
# Episode 822 Total Reward: 18.42
# Episode 823 Total Reward: 2.62
# Episode 824 Total Reward: 26.75
# Episode 825 Total Reward: 1.79
# Episode 826 Total Reward: -8.67
# Episode 827 Total Reward: 9.44
# Episode 828 Total Reward: -2.65
# Episode 829 Total Reward: 8.93
# Episode 830 Total Reward: 11.95
# Episode 831 Total Reward: 2.81
# Episode 832 Total Reward: -7.32
# Episode 833 Total Reward: 5.77
# Episode 834 Total Reward: 9.54
# Episode 835 Total Reward: 19.89
# Episode 836 Total Reward: -17.48
# Episode 837 Total Reward: 9.38
# Episode 838 Total Reward: 19.89
# Episode 839 Total Reward: -13.13
# Episode 840 Total Reward: 18.91
# Episode 841 Total Reward: -1.18
# Episode 842 Total Reward: 9.09
# Episode 843 Total Reward: 12.99
# Episode 844 Total Reward: 22.77
# Episode 845 Total Reward: 21.85
# Episode 846 Total Reward: 7.97
# Episode 847 Total Reward: 14.50
# Episode 848 Total Reward: -11.68
# Episode 849 Total Reward: -7.10
# Episode 850 Total Reward: 11.91
# Episode 851 Total Reward: 13.52
# Episode 852 Total Reward: -6.63
# Episode 853 Total Reward: 8.97
# Episode 854 Total Reward: 21.36
# Episode 855 Total Reward: 19.89
# Episode 856 Total Reward: 10.83
# Episode 857 Total Reward: 17.93
# Episode 858 Total Reward: -7.54
# Episode 859 Total Reward: -8.64
# Episode 860 Total Reward: -18.66
# Episode 861 Total Reward: 5.40
# Episode 862 Total Reward: -0.38
# Episode 863 Total Reward: 10.09
# Episode 864 Total Reward: 10.85
# Episode 865 Total Reward: 12.42
# Episode 866 Total Reward: 7.30
# Episode 867 Total Reward: -0.05
# Episode 868 Total Reward: 22.34
# Episode 869 Total Reward: 7.15
# Episode 870 Total Reward: -4.50
# Episode 871 Total Reward: 6.48
# Episode 872 Total Reward: 19.40
# Episode 873 Total Reward: 13.52
# Episode 874 Total Reward: 17.89
# Episode 875 Total Reward: 11.56
# Episode 876 Total Reward: -12.62
# Episode 877 Total Reward: 19.83
# Episode 878 Total Reward: 10.46
# Episode 879 Total Reward: 16.95
# Episode 880 Total Reward: 11.07
# Episode 881 Total Reward: 14.83
# Episode 882 Total Reward: 7.15
# Episode 883 Total Reward: 3.70
# Episode 884 Total Reward: 11.46
# Episode 885 Total Reward: 17.44
# Episode 886 Total Reward: 23.32
# Episode 887 Total Reward: 22.81
# Episode 888 Total Reward: -33.21
# Episode 889 Total Reward: -8.61
# Episode 890 Total Reward: 22.34
# Episode 891 Total Reward: 11.93
# Episode 892 Total Reward: 14.01
# Episode 893 Total Reward: -5.10
# Episode 894 Total Reward: 11.07
# Episode 895 Total Reward: 0.30
# Episode 896 Total Reward: 12.91
# Episode 897 Total Reward: 3.01
# Episode 898 Total Reward: 13.46
# Episode 899 Total Reward: -16.69
# Episode 900 Total Reward: 17.73
# Episode 901 Total Reward: 5.79
# Episode 902 Total Reward: 6.44
# Episode 903 Total Reward: 14.97
# Episode 904 Total Reward: 6.99
# Episode 905 Total Reward: 5.07
# Episode 906 Total Reward: -5.10
# Episode 907 Total Reward: 14.01
# Episode 908 Total Reward: 18.91
# Episode 909 Total Reward: 11.56
# Episode 910 Total Reward: -10.15
# Episode 911 Total Reward: 7.87
# Episode 912 Total Reward: -3.14
# Episode 913 Total Reward: 9.40
# Episode 914 Total Reward: 27.22
# Episode 915 Total Reward: 5.97
# Episode 916 Total Reward: -6.62
# Episode 917 Total Reward: -0.15
# Episode 918 Total Reward: 11.03
# Episode 919 Total Reward: 14.93
# Episode 920 Total Reward: 10.38
# Episode 921 Total Reward: 15.46
# Episode 922 Total Reward: 11.07
# Episode 923 Total Reward: 10.32
# Episode 924 Total Reward: 23.79
# Episode 925 Total Reward: -2.16
# Episode 926 Total Reward: 6.91
# Episode 927 Total Reward: -13.10
# Episode 928 Total Reward: 5.36
# Episode 929 Total Reward: 7.07
# Episode 930 Total Reward: -7.09
# Episode 931 Total Reward: 14.46
# Episode 932 Total Reward: -5.05
# Episode 933 Total Reward: 9.50
# Episode 934 Total Reward: 15.85
# Episode 935 Total Reward: -2.62
# Episode 936 Total Reward: 4.24
# Episode 937 Total Reward: -9.10
# Episode 938 Total Reward: -5.10
# Episode 939 Total Reward: -3.14
# Episode 940 Total Reward: 7.89
# Episode 941 Total Reward: 11.93
# Episode 942 Total Reward: -2.09
# Episode 943 Total Reward: -1.13
# Episode 944 Total Reward: 12.05
# Episode 945 Total Reward: -12.64
# Episode 946 Total Reward: 8.91
# Episode 947 Total Reward: 12.40
# Episode 948 Total Reward: 18.91
# Episode 949 Total Reward: -28.13
# Episode 950 Total Reward: 17.93
# Episode 951 Total Reward: 5.62
# Episode 952 Total Reward: -10.16
# Episode 953 Total Reward: 15.44
# Episode 954 Total Reward: 11.32
# Episode 955 Total Reward: 13.03
# Episode 956 Total Reward: 19.89
# Episode 957 Total Reward: 23.81
# Episode 958 Total Reward: 10.87
# Episode 959 Total Reward: 13.89
# Episode 960 Total Reward: 19.40
# Episode 961 Total Reward: 12.91
# Episode 962 Total Reward: 29.77
# Episode 963 Total Reward: 9.34
# Episode 964 Total Reward: 3.15
# Episode 965 Total Reward: 11.99
# Episode 966 Total Reward: 17.28
# Episode 967 Total Reward: -9.07
# Episode 968 Total Reward: 21.36
# Episode 969 Total Reward: 12.50
# Episode 970 Total Reward: -5.18
# Episode 971 Total Reward: -10.74
# Episode 972 Total Reward: 15.97
# Episode 973 Total Reward: 3.64
# Episode 974 Total Reward: -3.13
# Episode 975 Total Reward: -12.23
# Episode 976 Total Reward: 14.42
# Episode 977 Total Reward: 17.91
# Episode 978 Total Reward: 2.42
# Episode 979 Total Reward: 23.32
# Episode 980 Total Reward: 8.62
# Episode 981 Total Reward: 23.81
# Episode 982 Total Reward: 20.28
# Episode 983 Total Reward: 16.87
# Episode 984 Total Reward: 23.32
# Episode 985 Total Reward: -3.66
# Episode 986 Total Reward: -13.15
# Episode 987 Total Reward: -9.18
# Episode 988 Total Reward: 17.44
# Episode 989 Total Reward: 18.42
# Episode 990 Total Reward: -5.59
# Episode 991 Total Reward: -12.61
# Episode 992 Total Reward: 15.97
# Episode 993 Total Reward: -12.54
# Episode 994 Total Reward: 13.52
# Episode 995 Total Reward: -11.69
# Episode 996 Total Reward: 8.87
# Episode 997 Total Reward: 17.83
# Episode 998 Total Reward: 20.87
# Episode 999 Total Reward: 15.44

# %%
def evaluate_agent(env, model, episodes=20, render=False):
    total_rewards = []
    for ep in range(episodes):
        state, _ = env.reset()
        done = False
        ep_reward = 0
        steps = 0
        while not done:
            if render:
                env.render()
            with torch.no_grad():
                state_tensor = torch.FloatTensor(state).unsqueeze(0)
                q_values = model(state_tensor)
                action_idx = torch.argmax(q_values).item()
            # Decoding the action index to the (a1, a2) pair
            a1 = action_idx // 3
            a2 = action_idx % 3
            action = [a1, a2]
            next_state, reward, terminated, truncated, _ = env.step(action)
            done = terminated or truncated
            ep_reward += reward
            state = next_state
            steps += 1
        print(f"Test Episode {ep+1}: Reward={ep_reward:.2f}, Steps={steps}")
        total_rewards.append(ep_reward)
    avg = np.mean(total_rewards)
    print(f"\nAverage test reward over {episodes} episodes: {avg:.2f}")
    env.close()
    return total_rewards

# Example usage (should be after training, with trained model):
test_rewards = evaluate_agent(env, model, episodes=20, render=False)
# Out:
# Test Episode 1: Reward=9.60, Steps=40
# Test Episode 2: Reward=-15.60, Steps=60
# Test Episode 3: Reward=14.71, Steps=79
# Test Episode 4: Reward=-5.10, Steps=10
# Test Episode 5: Reward=8.87, Steps=63
# Test Episode 6: Reward=-6.58, Steps=58
# Test Episode 7: Reward=-7.17, Steps=67
# Test Episode 8: Reward=18.83, Steps=67
# Test Episode 9: Reward=-2.09, Steps=59
# Test Episode 10: Reward=12.48, Steps=52
# Test Episode 11: Reward=-23.58, Steps=58
# Test Episode 12: Reward=14.50, Steps=50
# Test Episode 13: Reward=16.46, Steps=54
# Test Episode 14: Reward=23.75, Steps=75
# Test Episode 15: Reward=13.01, Steps=49
# Test Episode 16: Reward=-1.50, Steps=50
# Test Episode 17: Reward=12.05, Steps=45
# Test Episode 18: Reward=25.28, Steps=72
# Test Episode 19: Reward=13.03, Steps=47
# Test Episode 20: Reward=1.76, Steps=24
#
# Average test reward over 20 episodes: 6.14
